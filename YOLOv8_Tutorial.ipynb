# %% [markdown]
# <a href="https://colab.research.google.com/github/ziweek/YOLO/blob/main/YOLOv8_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/107.7 GB disk)

# %%
from ultralytics import YOLO
from google.colab.patches import cv2_imshow

model = YOLO('yolov8n.pt')

result = model.predict(
   source="./test.png",
   conf=0.25
)
plots = result[0].plot()

cv2_imshow(plots)
# Out:
# image 1/1 /content/test.png: 320x640 2 persons, 213.0ms
# Speed: 4.2ms preprocess, 213.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=1032x510>
